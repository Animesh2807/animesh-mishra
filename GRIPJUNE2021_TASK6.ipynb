# %% [markdown]
# ## TASK 6: Prediction using Decision Tree Algorithm
#
# GRIP JUNE 2021 Data Science and Business Analytics Internship

# %% [markdown]
# ## Intern : Animesh Mishra

# %%
# Importing libraries in Python
import sklearn.datasets as datasets
import pandas as pd

# Loading the iris dataset
iris=datasets.load_iris()

# Forming the iris dataframe
features_frame = pd.DataFrame(iris.data, columns=iris.feature_names)
target_frame =iris.target
features_frame['target'] = target_frame

# %% [markdown]
# ### Exploring the iris dataset
# This data sets consists of 3 different types of irises’ (Setosa, Versicolour, and Virginica) petal and sepal length, stored in a 150x4 numpy.ndarray
#
# The rows being the samples and the columns being: Sepal Length, Sepal Width, Petal Length and Petal Width.

# %%
print(features_frame.head(10))
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
# 5                5.4               3.9                1.7               0.4
# 6                4.6               3.4                1.4               0.3
# 7                5.0               3.4                1.5               0.2
# 8                4.4               2.9                1.4               0.2
# 9                4.9               3.1                1.5               0.1

# %%
from collections import Counter as counter
categories = counter(target_frame)
print(categories)
# Out:
# Counter({0: 50, 1: 50, 2: 50})

# %% [markdown]
# ### Data Visualization

# %%
import matplotlib.pyplot as plt

labels = ['Iris Setosa', 'Iris Versicolor', 'Iris Virginica']
sizes = [categories[0],categories[1],categories[2]]
colors = ['yellowgreen', 'gold', 'lightskyblue']
patches, texts = plt.pie(sizes, colors=colors, shadow=True, startangle=90)
plt.legend(patches, labels, loc="best")
plt.axis('equal')
plt.tight_layout()
plt.show()

# %% [markdown]
# In the above fig, we can see that the target categories of iris dataset are divided in equal proportion.

# %%
#Finding the trend of different features in the respective categories 
df = pd.read_csv("Iris.csv")
type1_df = df[df.Species == "Iris-setosa"]
type2_df = df[df.Species == "Iris-versicolor"]
type3_df = df[df.Species == "Iris-virginica"]

# %%
#Analysis of Iris Setosa 
#1) Feature : Sepal
# a) length 
min_sepal_l1 = min(type1_df.SepalLengthCm)
max_sepal_l1 = max(type1_df.SepalLengthCm)
# b) width 
min_sepal_w1 = min(type1_df.SepalWidthCm)
max_sepal_w1 = max(type1_df.SepalWidthCm)

#2) Feature : Petal 
# a) length 
min_petal_l1 = min(type1_df.PetalLengthCm)
max_petal_l1 = max(type1_df.PetalLengthCm)
# b) width 
min_petal_w1 = min(type1_df.PetalWidthCm)
max_petal_w1 = max(type1_df.PetalWidthCm)

print(f"Iris Setosa Sepal length range: {min_sepal_l1} to {max_sepal_l1}")
print(f"Iris Setosa Sepal width range: {min_sepal_w1} to {max_sepal_w1}")
print(f"Iris Setosa Petal length range: {min_petal_l1} to {max_sepal_l1}")
print(f"Iris Setosa Petal width range: {min_petal_w1} to {max_sepal_w1}")
# Out:
# Iris Setosa Sepal length range: 4.3 to 5.8
# Iris Setosa Sepal width range: 2.3 to 4.4
# Iris Setosa Petal length range: 1.0 to 5.8
# Iris Setosa Petal width range: 0.1 to 4.4

# %%
#Analysis of Iris Versicolor
#1) Feature : Sepal
# a) length 
min_sepal_l2 = min(type2_df.SepalLengthCm)
max_sepal_l2 = max(type2_df.SepalLengthCm)
# b) width 
min_sepal_w2 = min(type2_df.SepalWidthCm)
max_sepal_w2 = max(type2_df.SepalWidthCm)

#2) Feature : Petal 
# a) length 
min_petal_l2 = min(type2_df.PetalLengthCm)
max_petal_l2 = max(type2_df.PetalLengthCm)
# b) width 
min_petal_w2 = min(type2_df.PetalWidthCm)
max_petal_w2 = max(type2_df.PetalWidthCm)

print(f"Iris Versicolor Sepal length range: {min_sepal_l2} to {max_sepal_l2}")
print(f"Iris Versicolor Sepal width range: {min_sepal_w2} to {max_sepal_w2}")
print(f"Iris Versicolor Petal length range: {min_petal_l2} to {max_sepal_l2}")
print(f"Iris Versicolor Petal width range: {min_petal_w2} to {max_sepal_w2}")
# Out:
# Iris Versicolor Sepal length range: 4.9 to 7.0
# Iris Versicolor Sepal width range: 2.0 to 3.4
# Iris Versicolor Petal length range: 3.0 to 7.0
# Iris Versicolor Petal width range: 1.0 to 3.4

# %%
#Analysis of Iris Verginicia
#1) Feature : Sepal
# a) length 
min_sepal_l3 = min(type3_df.SepalLengthCm)
max_sepal_l3 = max(type3_df.SepalLengthCm)
# b) width 
min_sepal_w3 = min(type3_df.SepalWidthCm)
max_sepal_w3 = max(type3_df.SepalWidthCm)

#2) Feature : Petal 
# a) length 
min_petal_l3 = min(type3_df.PetalLengthCm)
max_petal_l3 = max(type3_df.PetalLengthCm)
# b) width 
min_petal_w3 = min(type3_df.PetalWidthCm)
max_petal_w3 = max(type3_df.PetalWidthCm)

print(f"Iris Virginicia Sepal length range: {min_sepal_l3} to {max_sepal_l3}")
print(f"Iris Virginicia Sepal width range: {min_sepal_w3} to {max_sepal_w3}")
print(f"Iris Virginicia Petal length range: {min_petal_l3} to {max_sepal_l3}")
print(f"Iris Virginicia Petal width range: {min_petal_w3} to {max_sepal_w3}")
# Out:
# Iris Virginicia Sepal length range: 4.9 to 7.9
# Iris Virginicia Sepal width range: 2.2 to 3.8
# Iris Virginicia Petal length range: 4.5 to 7.9
# Iris Virginicia Petal width range: 1.4 to 3.8

# %%
# Scatter Plot showing classification based on Sepal length and Sepal width 
plt.scatter(type1_df.SepalLengthCm,type1_df.SepalWidthCm,c = "green",marker="o",s=50)
plt.scatter(type2_df.SepalLengthCm,type1_df.SepalWidthCm,c = "gold",marker="s",s=50)
plt.scatter(type3_df.SepalLengthCm,type1_df.SepalWidthCm,c = "lightskyblue",marker="^",s=50)
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.show()

# %% [markdown]
# From the above fig, we can easily examine that most of the data points are overlapping in range 5.0 to 7.0 approx.

# %%
# Scatter Plot showing classification based on Petal length and Petal width 
plt.scatter(type1_df.PetalLengthCm,type1_df.PetalWidthCm,c = "green",marker="o",s=50)
plt.scatter(type2_df.PetalLengthCm,type1_df.PetalWidthCm,c = "gold",marker="s",s=50)
plt.scatter(type3_df.PetalLengthCm,type1_df.PetalWidthCm,c = "lightskyblue",marker="^",s=50)
plt.xlabel("Petal Length")
plt.ylabel("Petal Width")
plt.show()

# %% [markdown]
# Above fig has shown some positive trends in the classification using the feature petal length and petal width.

# %% [markdown]
# ### Now let us define the Decision Tree Algorithm

# %%
# Defining the decision tree algorithm
from sklearn.tree import DecisionTreeClassifier
dtree=DecisionTreeClassifier()
dtree.fit(df,y)

print('Decision Tree Classifer Created')
# Out:
# Decision Tree Classifer Created

# %% [markdown]
# ### Let us visualize the Decision Tree to understand it better.

# %%
# Install required libraries
# !pip install pydotplus
# !apt-get install graphviz -y

# %%
# Import necessary libraries for graph viz
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus

# Visualize the graph
dot_data = StringIO()
export_graphviz(dtree, out_file=dot_data, feature_names=iris.feature_names,  
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())

# %% [markdown]
# ### Construction of Decision Tree Model

# %%
# 75% training data and 25% test data
# Here X_train,Y_train is training data while X_test,Y_test is testing data
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(features_frame[iris.feature_names], features_frame['target'], random_state=0)

# %%
from sklearn.tree import DecisionTreeClassifier
# Making an instance of the model 
clf = DecisionTreeClassifier()
# Training the model 
clf.fit(X_train, Y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# ### Visualising the trained Model

# %%
from sklearn import tree
fn=['sepal length (cm)','sepal width (cm)','petal length (cm)','petal width (cm)']
cn=['setosa', 'versicolor', 'virginica']
fig, axes = plt.subplots(nrows = 1,ncols = 1,figsize = (4,4), dpi=300)
tree.plot_tree(clf,
               feature_names = fn, 
               class_names=cn,
               filled = True);

# %% [markdown]
# ### Evaluating the performance of the model

# %%
accuracy_train = clf.score(X_train,Y_train)
accuracy_test = clf.score(X_test,Y_test)
print("Train Accuracy of the decision trees is found to be: ",accuracy_train)
print("Test Accuracy of the decision trees is found to be: ",accuracy_test)
# Out:
# Train Accuracy of the decision trees is found to be:  1.0
# Test Accuracy of the decision trees is found to be:  0.9736842105263158

# %%
from sklearn.metrics import precision_score
X_pred = clf.predict(X_train)
Y_pred = clf.predict(X_test)
train_micro_precision = precision_score(X_pred, Y_train, average="micro")
print('Micro-averaged precision score training data:',train_micro_precision)
test_micro_precision = precision_score(Y_pred, Y_test, average="micro")
print('Micro-averaged precision score testing data:',test_micro_precision)
# Out:
# Micro-averaged precision score training data: 1.0
# Micro-averaged precision score testing data: 0.9736842105263158

# %%
from sklearn.metrics import recall_score
train_micro_recall = recall_score(Y_train,X_pred,average="micro")
print(f"Micro-average recall score training data: {train_micro_recall}")
test_micro_recall = recall_score(Y_test,Y_pred,average="micro")
print(f"Micro-average recall score testing data: {test_micro_recall}")
# Out:
# Micro-average recall score: 1.0
# Micro-average recall score: 0.9736842105263158

# %% [markdown]
# As precision is equal to recall, there might be a probability that number of  False positive is equal to the number of False Negative
